# %% [markdown]
# <a href="https://colab.research.google.com/github/karishma-upadhyay/IIITH_Projects_and_Apps/blob/main/Module_4_project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Students Internship Batch of 2024**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(new_x)  # [REQUIRED] Calculate the gradient (derivative at new_x)
    new_x = new_x - step_multiplier * gradient  # [REQUIRED] Update new_x by moving against the gradient

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED] Append the new slope (derivative at new_x)

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2  # [REQUIRED] Define the function g(x), e.g., g(x) = x^2

def dg(x):
    return 2*x  # [REQUIRED] Define the derivative dg(x), e.g., dg(x) = 2x

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier
import numpy as np
import matplotlib.pyplot as plt

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2  # Define the function g(x)

def dg(x):
    return 2*x  # Define the derivative dg(x)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the function g(x)
ax1.plot(x_2, g(x_2), color='blue')
ax1.set_title('Function g(x)')
ax1.set_xlabel('x')
ax1.set_ylabel('g(x)')
ax1.grid(True)

# Plot the derivative dg(x)
ax2.plot(x_2, dg(x_2), color='red')
ax2.set_title('Derivative dg(x)')
ax2.set_xlabel('x')
ax2.set_ylabel('dg(x)')
ax2.grid(True)

# Show the plots
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.0234052067759206
# Number of steps: 76

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.004894871981406463
# Number of steps: 230

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.023960349927139895
# Number of steps: 36

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define the function g(x) and its derivative dg(x)
def g(x):
    return x**2  # Example function: g(x) = x^2

def dg(x):
    return 2*x  # Derivative: dg(x) = 2x

# Step 2: Implement Gradient Descent
new_x = 3  # Starting point
step_multiplier = 0.1  # Learning rate
precision = 0.00001  # Precision of the result

x_list = [new_x]
slope_list = [dg(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = dg(new_x)
    new_x = new_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    slope_list.append(dg(new_x))

    if step_size < precision:
        print('Gradient descent converged in', n, 'iterations.')
        break

print('Local minimum occurs at:', new_x)
print('Slope or dg(x) at this point is:', dg(new_x))
print('g(x) value at this point is:', g(new_x))

# Step 3: Plot the function and its derivative
x_2 = np.linspace(-2, 2, 1000)  # Range of x values

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the function g(x)
ax1.plot(x_2, g(x_2), color='blue')
ax1.set_title('Function g(x)')
ax1.set_xlabel('x')
ax1.set_ylabel('g(x)')
ax1.grid(True)

# Plot the derivative dg(x)
ax2.plot(x_2, dg(x_2), color='red')
ax2.set_title('Derivative dg(x)')
ax2.set_xlabel('x')
ax2.set_ylabel('dg(x)')
ax2.grid(True)

plt.show()
# Out:
# Gradient descent converged in 50 iterations.
# Local minimum occurs at: 3.425394462494306e-05
# Slope or dg(x) at this point is: 6.850788924988612e-05
# g(x) value at this point is: 1.1733327223686654e-09

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  109

# %%
## TASK-5 : Run gradient descent 3 times
import numpy as np
import matplotlib.pyplot as plt

def g(x):
    return x**2  # Example function: g(x) = x^2

def dg(x):
    return 2*x  # Derivative: dg(x) = 2x

def gradient_descent(starting_x, step_multiplier, precision=0.00001, max_iterations=500):
    new_x = starting_x
    x_list = [new_x]
    slope_list = [dg(new_x)]

    for n in range(max_iterations):
        previous_x = new_x
        gradient = dg(new_x)
        new_x = new_x - step_multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        slope_list.append(dg(new_x))

        if step_size < precision:
            print(f'Gradient descent converged in {n} iterations.')
            break

    return new_x, x_list, slope_list

# Define a function to print the results
def print_results(new_x):
    print('Local minimum occurs at:', new_x)
    print('Slope or dg(x) at this point is:', dg(new_x))
    print('g(x) value at this point is:', g(new_x))
# First Run
print("First Run:")
final_x1, x_list1, slope_list1 = gradient_descent(starting_x=3, step_multiplier=0.1)
print_results(final_x1)

# Second Run
print("\nSecond Run:")
final_x2, x_list2, slope_list2 = gradient_descent(starting_x=-3, step_multiplier=0.1)
print_results(final_x2)

# Third Run
print("\nThird Run:")
final_x3, x_list3, slope_list3 = gradient_descent(starting_x=0.5, step_multiplier=0.05)
print_results(final_x3)
# Plotting all three gradient descent paths

x_2 = np.linspace(-4, 4, 1000)

plt.figure(figsize=(12, 8))

# Plot the function g(x)
plt.plot(x_2, g(x_2), label='g(x) = x^2', color='blue')

# Plot the descent paths for each run
plt.scatter(x_list1, g(np.array(x_list1)), color='red', label='Descent Path 1 (start at 3)')
plt.scatter(x_list2, g(np.array(x_list2)), color='green', label='Descent Path 2 (start at -3)')
plt.scatter(x_list3, g(np.array(x_list3)), color='orange', label='Descent Path 3 (start at 0.5)')

plt.title('Gradient Descent Paths for g(x) = x^2')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# First Run:
# Gradient descent converged in 50 iterations.
# Local minimum occurs at: 3.425394462494306e-05
# Slope or dg(x) at this point is: 6.850788924988612e-05
# g(x) value at this point is: 1.1733327223686654e-09
#
# Second Run:
# Gradient descent converged in 50 iterations.
# Local minimum occurs at: -3.425394462494306e-05
# Slope or dg(x) at this point is: -6.850788924988612e-05
# g(x) value at this point is: 1.1733327223686654e-09
#
# Third Run:
# Gradient descent converged in 81 iterations.
# Local minimum occurs at: 8.848217271399877e-05
# Slope or dg(x) at this point is: 0.00017696434542799753
# g(x) value at this point is: 7.829094888189908e-09

# %%
## TASK-5 : Run gradient descent 3 times
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def g(x):
    return x**2  # The function g(x) = x^2

def dg(x):
    return 2*x  # The derivative of g(x), dg(x) = 2x

# Gradient Descent function
def gradient_descent(derivative_func, initial_guess, multiplier, precision=0.00001, max_iter=500):
    new_x = initial_guess
    x_list = [new_x]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(new_x)
        new_x = new_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)

        if step_size < precision:
            break

    return x_list

# Set the parameters for different learning rates
n = 100
low_gamma = gradient_descent(dg, 3, 0.0005, 0.0001, n)
mid_gamma = gradient_descent(dg, 3, 0.001, 0.0001, n)  # Mid learning rate
high_gamma = gradient_descent(dg, 3, 0.002, 0.0001, n)  # High learning rate
insane_gamma = gradient_descent(dg, 1.9, 0.25, 0.0001, n)  # Extremely high learning rate

# Plotting the results
x_2 = np.linspace(-2, 3, 1000)

plt.figure(figsize=(14, 8))

# Plot the function g(x)
plt.plot(x_2, g(x_2), label='g(x) = x^2', color='blue')

# Plot the descent paths for each learning rate
plt.plot(low_gamma, g(np.array(low_gamma)), color='red', label='Low learning rate (0.0005)')
plt.plot(mid_gamma, g(np.array(mid_gamma)), color='green', label='Mid learning rate (0.001)')
plt.plot(high_gamma, g(np.array(high_gamma)), color='orange', label='High learning rate (0.002)')
plt.plot(insane_gamma, g(np.array(insane_gamma)), color='purple', label='Insane learning rate (0.25)')

plt.title('Gradient Descent with Different Learning Rates')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
## TASK-7 : Plot reduction in cost for each iteration
def gradient_descent(derivative_func, initial_guess, multiplier, precision=0.00001, max_iter=500):
    new_x = initial_guess
    x_list = [new_x]
    cost_list = [g(new_x)]  # Track cost (function value)

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(new_x)
        new_x = new_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        cost_list.append(g(new_x))  # Store cost at this iteration

        if step_size < precision:
            break

    return x_list, cost_list
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def g(x):
    return x**2  # The function g(x) = x^2

def dg(x):
    return 2*x  # The derivative of g(x), dg(x) = 2x

# Gradient Descent function with cost tracking
def gradient_descent(derivative_func, initial_guess, multiplier, precision=0.00001, max_iter=500):
    new_x = initial_guess
    x_list = [new_x]
    cost_list = [g(new_x)]  # Track cost (function value)

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(new_x)
        new_x = new_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        cost_list.append(g(new_x))  # Store cost at this iteration

        if step_size < precision:
            break

    return x_list, cost_list

# Set the parameters for different learning rates
n = 100
low_gamma_x, low_gamma_cost = gradient_descent(dg, 3, 0.0005, 0.0001, n)
mid_gamma_x, mid_gamma_cost = gradient_descent(dg, 3, 0.001, 0.0001, n)
high_gamma_x, high_gamma_cost = gradient_descent(dg, 3, 0.002, 0.0001, n)
insane_gamma_x, insane_gamma_cost = gradient_descent(dg, 1.9, 0.25, 0.0001, n)

# Plot the reduction in cost for each learning rate
plt.figure(figsize=(14, 8))

plt.plot(low_gamma_cost, label='Low learning rate (0.0005)', color='red')
plt.plot(mid_gamma_cost, label='Mid learning rate (0.001)', color='green')
plt.plot(high_gamma_cost, label='High learning rate (0.002)', color='orange')
plt.plot(insane_gamma_cost, label='Insane learning rate (0.25)', color='purple')

plt.title('Cost Reduction Over Iterations for Different Learning Rates')
plt.xlabel('Iteration')
plt.ylabel('Cost (g(x))')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

import numpy as np
import matplotlib.pyplot as plt

# Define the new function and its derivative
def h(x):
    return x**3 - 4*x  # Example function: h(x) = x^3 - 4x

def dh(x):
    return 3*x**2 - 4  # Derivative: dh(x) = 3x^2 - 4

# Gradient Descent function with cost tracking
def gradient_descent(derivative_func, initial_guess, multiplier, precision=0.00001, max_iter=500):
    new_x = initial_guess
    x_list = [new_x]
    cost_list = [h(new_x)]  # Track cost (function value)

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(new_x)
        new_x = new_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        cost_list.append(h(new_x))  # Store cost at this iteration

        if step_size < precision:
            break

    return x_list, cost_list

# Plot the function and its derivative
x_vals = np.linspace(-3, 3, 1000)

plt.figure(figsize=(14, 6))

# Plot the function h(x)
plt.subplot(1, 2, 1)
plt.plot(x_vals, h(x_vals), label='h(x) = x^3 - 4x', color='blue')
plt.title('Function h(x)')
plt.xlabel('x')
plt.ylabel('h(x)')
plt.grid(True)

# Plot the derivative dh(x)
plt.subplot(1, 2, 2)
plt.plot(x_vals, dh(x_vals), label='dh(x) = 3x^2 - 4', color='orange')
plt.title('Derivative dh(x)')
plt.xlabel('x')
plt.ylabel('dh(x)')
plt.grid(True)

plt.tight_layout()
plt.show()

# Run Gradient Descent with different learning rates
n = 100
low_gamma_x, low_gamma_cost = gradient_descent(dh, 3, 0.0005, 0.0001, n)
mid_gamma_x, mid_gamma_cost = gradient_descent(dh, 3, 0.001, 0.0001, n)
high_gamma_x, high_gamma_cost = gradient_descent(dh, 3, 0.002, 0.0001, n)
insane_gamma_x, insane_gamma_cost = gradient_descent(dh, 1.9, 0.25, 0.0001, n)

# Plot the reduction in cost for each learning rate
plt.figure(figsize=(14, 8))

plt.plot(low_gamma_cost, label='Low learning rate (0.0005)', color='red')
plt.plot(mid_gamma_cost, label='Mid learning rate (0.001)', color='green')
plt.plot(high_gamma_cost, label='High learning rate (0.002)', color='orange')
plt.plot(insane_gamma_cost, label='Insane learning rate (0.25)', color='purple')

plt.title('Cost Reduction Over Iterations for Different Learning Rates')
plt.xlabel('Iteration')
plt.ylabel('Cost (h(x))')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm

# Define the function that can handle numpy arrays
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Calculate the Z values
z_4 = f(x_4, y_4)

# Plot the surface
ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
# !pip install sympy
import sympy
from sympy import symbols, diff
from sympy import *

a, b = symbols('x, y')
# Define the function symbolically using sympy
f = sympy.sin(sympy.sqrt(a**2 + b**2))

print('Our cost function f(x, y) is: ', f)
print('Partial derivative wrt x is: ', diff(f, b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f.evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f, a).evalf(subs={a:1.8, b:1.0}))
# Out:
# ...
# Our cost function f(x, y) is:  sin(sqrt(x**2 + y**2))
# Partial derivative wrt x is:  y*cos(sqrt(x**2 + y**2))/sqrt(x**2 + y**2)
# Value of f(x,y) at x=1.8 y=1.0 is:  0.883117713196773
# Value of partial derivative wrt x:  -0.410112173744750

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(sympy.sin(sympy.sqrt(a**2 + b**2)), a).evalf(subs={a:params[0], b:params[1]}) # Use sympy.sin instead of f
    gradient_y = diff(sympy.sin(sympy.sqrt(a**2 + b**2)), b).evalf(subs={a:params[0], b:params[1]}) # Use sympy.sin instead of f
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f.evalf(subs={a:params[0], b:params[1]})) # Use f.evalf for symbolic evaluation
# Out:
# Values in gradient array [-3.81217567902896e-15 -2.11787537723831e-15]
# Minimum occurs at x value of:  4.11936911511823
# Minimum occurs at y value of:  2.28853839728790
# The cost is:  -1.00000000000000

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
import numpy as np

# Define the function f(x, y)
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Partial derivative with respect to x
def fpx(x, y):
    r = np.sqrt(x**2 + y**2)
    return np.cos(r) * (x / r) if r != 0 else 0

# Partial derivative with respect to y
def fpy(x, y):
    r = np.sqrt(x**2 + y**2)
    return np.cos(r) * (y / r) if r != 0 else 0

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [-3.26621060e-15 -1.81456144e-15]
# Minimum occurs at x value of:  4.119369115118229
# Minimum occurs at y value of:  2.2885383972879025
# The cost is:  -1.0

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [-6.41083832e-09 -3.56157684e-09]
# Minimum occurs at x value of:  4.119369109348478
# Minimum occurs at y value of:  2.2885383940824857
# The cost is:  -1.0

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

import numpy as np

def mse(y, y_hat):
    """
    Compute the Mean Squared Error (MSE) between true values and predicted values.

    Parameters:
    y (array-like): True values
    y_hat (array-like): Predicted values

    Returns:
    float: Mean Squared Error
    """
    y = np.array(y)
    y_hat = np.array(y_hat)
    return np.mean((y - y_hat) ** 2)

# Example usage
# Assuming y and y_hat are defined
y = np.array([3, -0.5, 2, 7])  # Example true values
y_hat = np.array([2.5, 0.0, 2, 8])  # Example predicted values

# Calculate MSE
error = mse(y, y_hat)
print("Mean Squared Error:", error)

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc
# Out:
# Mean Squared Error: 0.375

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# <ipython-input-47-050b7bf9b7b1>:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plot_cost[i][j] = mse(y_5, y_hat)
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
